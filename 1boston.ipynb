# %%
# !pip install tensorflow
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

df = pd.read_csv('BostonHousing.csv')
df.head(n=10)
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.21.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (4.4 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Users/karanpatil/Desktop/Machine Learning/Python/venv/lib/python3.12/site-packages (from tensorflow) (25.0)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Using cached protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: setuptools in /Users/karanpatil/Desktop/Machine Learning/Python/venv/lib/python3.12/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/karanpatil/Desktop/Machine Learning/Python/venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting typing_extensions>=3.6.6 (from tensorflow)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.1.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.80.0-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Using cached keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in /Users/karanpatil/Desktop/Machine Learning/Python/venv/lib/python3.12/site-packages (from tensorflow) (2.3.5)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (8.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Downloading charset_normalizer-3.4.7-cp312-cp312-macosx_10_13_universal2.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests<3,>=2.21.0->tensorflow)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests<3,>=2.21.0->tensorflow)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/karanpatil/Desktop/Machine Learning/Python/venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.12.0->tensorflow)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Using cached optree-0.19.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.12.0->tensorflow)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/karanpatil/Desktop/Machine Learning/Python/venv/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached tensorflow-2.21.0-cp312-cp312-macosx_12_0_arm64.whl (223.5 MB)
# Using cached grpcio-1.80.0-cp312-cp312-macosx_11_0_universal2.whl (12.0 MB)
# Downloading h5py-3.14.0-cp312-cp312-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 6.7 MB/s  0:00:00 eta 0:00:01
# Using cached ml_dtypes-0.5.4-cp312-cp312-macosx_10_13_universal2.whl (676 kB)
# Using cached protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl (429 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp312-cp312-macosx_10_13_universal2.whl (311 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached keras-3.14.0-py3-none-any.whl (1.6 MB)
# Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp312-cp312-macosx_11_0_arm64.whl (61 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Using cached optree-0.19.0-cp312-cp312-macosx_11_0_arm64.whl (388 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, urllib3, typing_extensions, termcolor, protobuf, opt_einsum, ml_dtypes, mdurl, idna, h5py, google_pasta, gast, charset_normalizer, certifi, astunparse, absl-py, requests, optree, markdown-it-py, grpcio, rich, keras, tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/26 [tensorflow]6 [tensorflow]
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 certifi-2026.4.22 charset_normalizer-3.4.7 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 idna-3.13 keras-3.14.0 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 protobuf-7.34.1 requests-2.33.1 rich-15.0.0 tensorflow-2.21.0 termcolor-3.3.0 typing_extensions-4.15.0 urllib3-2.6.3 wrapt-2.1.2
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# 5  394.12   5.21  28.7
# 6  395.60  12.43  22.9
# 7  396.90  19.15  27.1
# 8  386.63  29.93  16.5
# 9  386.71  17.10  18.9

# %%
# df.drop(columns=['CAT. MEDV'],inplace=True)
# df.dropna(inplace=True)
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.corr()['medv'].sort_values()
# Out:
# lstat     -0.737663
# ptratio   -0.507787
# indus     -0.483725
# tax       -0.468536
# nox       -0.427321
# crim      -0.388305
# rad       -0.381626
# age       -0.376955
# chas       0.175260
# dis        0.249929
# b          0.333461
# zn         0.360445
# rm         0.695360
# medv       1.000000
# Name: medv, dtype: float64

# %%
X = df.loc[:, df.columns != 'medv'].values  #or X = df.loc[:,['lstat','ptratio','rm]]
y = df.loc[:, df.columns == 'medv'].values  #or y = df.loc[:,'medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=45)

# %% [markdown]
# ### Normalizing Training and Testing Data Set

# %%
scaler = StandardScaler() #standardise (Z-score normalization => mean = 0 and Std = 1)
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ##### input_shape=(13,): This parameter defines the shape of the input data for the first layer. In this case, it expects input data with 13 features.
# ##### activation='relu': This parameter specifies the activation function to be used in the layer. Activation functions introduce non-linearity to the network, enabling it to learn complex patterns. In this case, the Rectified Linear Unit (ReLU) activation function is used, which returns the input if it is positive and 0 otherwise.
# ##### optimizer='adam': This parameter specifies the optimization algorithm used during training. Adam (Adaptive Moment Estimation) is a popular optimization algorithm known for its efficiency and effectiveness in a wide range of deep learning tasks.
#
# ##### loss='mse': This parameter defines the loss function used to measure the difference between the predicted output and the true output during training. MSE (Mean Squared Error) is a common loss function for regression tasks that calculates the average squared difference between the predicted and true values.
#
# ##### metrics=['mae']: This parameter specifies the evaluation metric(s) used to monitor the model's performance during training. MAE (Mean Absolute Error) is a metric that measures the average absolute difference between the predicted and true values. It provides a measure of the model's accuracy.

# %% [markdown]
# ``` Adam optimizer dynamically adjusts the learning rates for individual parameters in a neural network based on the history of gradients. This adaptive learning rate strategy helps improve the efficiency and robustness of the optimization process during training. ```

# %%
model = Sequential(layers=[Dense(128, input_shape=(13, ), activation='relu', name='dense_1'),Dense(64, activation='relu', name='dense_2'),Dense(1, activation='linear', name='dense_output')])


# model.add(Dense(128, input_shape=(13, ), activation='relu', name='dense_1'))
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6899 - mae: 2.0025 - val_loss: 5.3729 - val_mae: 1.8494
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6492 - mae: 1.9869 - val_loss: 5.1856 - val_mae: 1.8481
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4526 - mae: 1.9623 - val_loss: 5.1632 - val_mae: 1.8237
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3894 - mae: 1.9647 - val_loss: 5.4667 - val_mae: 1.8959
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3532 - mae: 1.9551 - val_loss: 5.3857 - val_mae: 1.9368
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4166 - mae: 1.9523 - val_loss: 4.9679 - val_mae: 1.8596
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2307 - mae: 1.9378 - val_loss: 5.6177 - val_mae: 1.9369
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1567 - mae: 1.9377 - val_loss: 5.2795 - val_mae: 1.9045
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0466 - mae: 1.9227 - val_loss: 5.4505 - val_mae: 1.9235
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9986 - mae: 1.9166 - val_loss: 5.4404 - val_mae: 1.9501
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9105 - mae: 1.9063 - val_loss: 5.4231 - val_mae: 1.9723
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8631 - mae: 1.8902 - val_loss: 5.6797 - val_mae: 2.0040
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8411 - mae: 1.8908 - val_loss: 5.4280 - val_mae: 1.9788
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0478 - mae: 1.9242 - val_loss: 4.9847 - val_mae: 1.8830
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9672 - mae: 1.9019 - val_loss: 6.3127 - val_mae: 2.0975
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3765 - mae: 1.9478 - val_loss: 4.6319 - val_mae: 1.8058
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8206 - mae: 1.8924 - val_loss: 7.8241 - val_mae: 2.1919
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7261 - mae: 1.8731 - val_loss: 5.6041 - val_mae: 1.9266
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6018 - mae: 1.8841 - val_loss: 5.4125 - val_mae: 1.9245
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4626 - mae: 1.8440 - val_loss: 5.5438 - val_mae: 1.9591
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3113 - mae: 1.8192 - val_loss: 4.9787 - val_mae: 1.8811
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3352 - mae: 1.8376 - val_loss: 5.3285 - val_mae: 1.9293
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3388 - mae: 1.8335 - val_loss: 5.5427 - val_mae: 1.9965
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4839 - mae: 1.8546 - val_loss: 5.4426 - val_mae: 1.9464
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3997 - mae: 1.8710 - val_loss: 4.7033 - val_mae: 1.7916
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2792 - mae: 1.8576 - val_loss: 5.8536 - val_mae: 2.0072
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0120 - mae: 1.7768 - val_loss: 5.2130 - val_mae: 1.9144
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9239 - mae: 1.7615 - val_loss: 5.0436 - val_mae: 1.8864
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9288 - mae: 1.7783 - val_loss: 5.4446 - val_mae: 1.9391
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9191 - mae: 1.7866 - val_loss: 4.7441 - val_mae: 1.8554
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9143 - mae: 1.7669 - val_loss: 5.4645 - val_mae: 1.9551
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9545 - mae: 1.7693 - val_loss: 5.2883 - val_mae: 1.9499
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7949 - mae: 1.7628 - val_loss: 6.3092 - val_mae: 2.1257

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(X_test)
mse_nn, mae_nn= model.evaluate(X_test, y_test)
r2 = r2_score(y_test, y_pred)

print('Mean squared error on test data: ', mse_nn)
print('Mean absolute error on test data: ', mae_nn)
print('Accuracy:', r2*100)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.1600 - mae: 2.6108
# Mean squared error on test data:  13.159987449645996
# Mean absolute error on test data:  2.610771656036377
# Accuracy: 87.01236506656184

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred, c='green')

p1 = max(max(y_pred), max(y_test))
p2 = min(min(y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()
